# %% [markdown]
# # Hallucinations & Grounding + RAG Evaluation Basics
# ### Practice Notebook (Deliverable Work Session)
#
# **Assumed pre-installed libraries:** `numpy`, `scikit-learn`,
# `sentence-transformers`, `chromadb`
#
# This notebook is the capstone work session for the week: you'll assemble the
# retrieval pipeline from Days 2–4 into a small end-to-end system, then build
# simple metrics to evaluate whether its answers are actually grounded in the
# retrieved context.

# %%
# !pip install chromadb
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from chromadb.utils import embedding_functions
import numpy as np
import chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.6.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (2.13.5)
# Collecting pydantic-settings>=2.0 (from chromadb)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.5.0-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.4)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.13/dist-packages (from chromadb) (2.1.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (4.16.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.30.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (1.42.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.13/dist-packages (from chromadb) (0.23.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (1.83.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (0.27.2)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.13/dist-packages (from chromadb) (5.3.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.13/dist-packages (from chromadb) (3.12.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (4.26.0)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.13/dist-packages (from build>=1.0.3->chromadb) (26.3)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (1.9.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.4)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.11-py3-none-any.whl.metadata (474 bytes)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (3.14.3)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.13/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb) (0.4.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings>=2.0->chromadb) (1.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=10.11.0->chromadb) (2.21.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.13/dist-packages (from tokenizers>=0.13.2->chromadb) (1.29.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (8.5.0)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.5)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 66.3 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 12.4 MB/s eta 0:00:00
# Downloading build-1.6.1-py3-none-any.whl (31 kB)
# Downloading kubernetes-36.0.3-py2.py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 79.4 MB/s eta 0:00:00
# Downloading onnxruntime-1.30.0-cp313-cp313-manylinux_2_28_x86_64.whl (23.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 21.3 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 3.5 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 7.7 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.3 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 9.3 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.5.0-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 5.0 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 2.2 MB/s eta 0:00:00
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.7 MB/s eta 0:00:00
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading durationpy-0.11-py3-none-any.whl (4.1 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pypika, durationpy, pyproject_hooks, pybase64, overrides, opentelemetry-proto, opentelemetry-api, onnxruntime, importlib-resources, bcrypt, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, build, pydantic-settings, opentelemetry-sdk, kubernetes, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.42.1
#     Uninstalling opentelemetry-api-1.42.1:
#       Successfully uninstalled opentelemetry-api-1.42.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.63b1
#     Uninstalling opentelemetry-semantic-conventions-0.63b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.63b1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.42.1
#     Uninstalling opentelemetry-sdk-1.42.1:
#       Successfully uninstalled opentelemetry-sdk-1.42.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 2.7.1 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.7.1 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# Successfully installed bcrypt-5.0.0 build-1.6.1 chromadb-1.5.9 durationpy-0.11 importlib-resources-7.1.0 kubernetes-36.0.3 onnxruntime-1.30.0 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-grpc-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 overrides-7.7.0 pybase64-1.5.0 pydantic-settings-2.15.0 pypika-0.51.1 pyproject_hooks-1.2.0

# %% [markdown]
# ## 1. Why LLMs hallucinate
#
# A few root causes worth covering explicitly in class:
#
# 1. **Next-token prediction, not fact lookup** — the model is optimized to
#    produce plausible-sounding continuations, not to check a claim against
#    a source of truth. Fluency and correctness are optimized differently.
# 2. **Knowledge gaps** — questions about things outside training data (recent
#    events, private data, long-tail facts) leave the model "guessing" from
#    loosely related patterns.
# 3. **Prompt ambiguity / underspecification** — a vague question invites the
#    model to fill gaps with invented specifics.
# 4. **Compounding errors in reasoning chains** — a small early error (e.g., a
#    wrong intermediate number) can snowball into a confidently wrong final
#    answer, especially in longer chain-of-thought generations.
# 5. **Sycophancy / pattern completion** — the model may complete a pattern the
#    user's phrasing implies is true, even when it isn't (e.g., a leading
#    question that assumes a false premise).
#
# RAG doesn't eliminate hallucination — it reduces one specific class of it
# (missing/out-of-date knowledge) by handing the model a source to work from.
# But the model can still ignore or misread that source. That's what we'll
# measure below.

# %% [markdown]
# ## 2. Grounding techniques to reduce hallucination
#
# - **Retrieval + explicit instruction** — "answer ONLY using the context
#   below; say 'I don't know' if it's not there" (you already did this on
#   Day 1's `augment_prompt`).
# - **Citations** — require the model to tag each claim with the source chunk
#   it came from; makes ungrounded claims easy to spot (no citation = suspect).
# - **Confidence/abstention thresholds** — if retrieval similarity scores are
#   all low (nothing relevant was found), have the system refuse to answer
#   rather than forcing a guess.
# - **Answer verification pass** — a second LLM call (or a lighter heuristic
#   check) that checks whether the generated answer is actually supported by
#   the retrieved context, before returning it to the user.
# - **Structured output constraints** — asking for answers in a format that's
#   easy to verify programmatically (e.g., a JSON object with an `evidence`
#   field) rather than free-flowing prose.
#
# Let's build a simple version of the last two: an abstention threshold and a
# lightweight groundedness check.

# %% [markdown]
# ## 3. Assemble the mini end-to-end RAG pipeline
#
# We'll reuse the same building blocks from earlier in the week: chunking
# (Day 2), embeddings + semantic search (Day 3), and a vector store (Day 4).

# %%
import chromadb
from chromadb.utils import embedding_functions

chroma_client = chromadb.Client()

local_ef = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="all-MiniLM-L6-v2"
)

print("ChromaDB initialized successfully!")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ChromaDB initialized successfully!

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

collection = chroma_client.get_or_create_collection(

    name="rag_eval_practice",

    embedding_function=local_ef

)

knowledge_base = [

    {"id": "doc1", "text": "Our Q3 refund policy allows exceptions for orders "
                            "delayed more than 10 business days, approved by a "
                            "supervisor. Order #48213 was delayed 14 days and "
                            "was granted a full refund on 2025-08-02."},

    {"id": "doc2", "text": "Standard refund policy: refunds are issued within "
                            "5-7 business days of a return being received."},

    {"id": "doc3", "text": "Our shipping partners include BlueDart, Delhivery, "
                            "and DTDC for domestic orders across India."},

    {"id": "doc4", "text": "Customer support is available 9am-9pm IST, "
                            "Monday through Saturday, via chat and email."},

]

collection.add(

    documents=[d["text"] for d in knowledge_base],

    ids=[d["id"] for d in knowledge_base],

)

print("Indexed", collection.count(), "documents")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Indexed 4 documents

# %%
def retrieve(query: str, k: int = 2):
    results = collection.query(query_texts=[query], n_results=k)
    docs = results["documents"][0]
    distances = results["distances"][0]
    # Chroma's default distance is squared L2. For unit-normalized embeddings,
    # squared L2 distance d relates to cosine similarity as: cos_sim = 1 - d/2.
    # We surface BOTH numbers below -- do not trust a single "similarity-like"
    # score without checking what it actually implies.
    scores = [1 / (1 + d) for d in distances]
    implied_cosine = [1 - d / 2 for d in distances]
    return list(zip(docs, scores, implied_cosine))

def generate_stub(query: str, retrieved: list, min_score: float = 0.6) -> dict:
    """Stub generator with an ABSTENTION THRESHOLD: if nothing retrieved
    clears min_score (on the implied-cosine scale), refuse to answer instead
    of guessing.
    IMPORTANT: 0.6 is NOT a universal safe number -- it was picked after
    inspecting this specific corpus and embedding model's score spread (see
    Exercise 5.1). A different corpus, embedding model, or query set could
    shift "unrelated" scores above or below this line. Never hard-code a
    threshold without checking it against real relevant/irrelevant examples
    for your actual data.
    Replace the body with a real LLM call in production:
        # TODO: replace with a real LLM call, still passing `context`
    """
    usable = [(doc, cos) for doc, score, cos in retrieved if cos >= min_score]
    if not usable:
        return {"answer": "I don't have enough information to answer that.",
                "grounded_in": [], "abstained": True}
    context = " ".join(doc for doc, _ in usable)
    return {"answer": f"(stub) Based on available context: {context[:200]}...",
            "grounded_in": [doc for doc, _ in usable], "abstained": False}

for q in ["What's the refund policy for order #48213?",
          "What is the capital of France?"]:
    retrieved = retrieve(q)
    print("Query:", q)
    for doc, score, cos in retrieved:
        print(f"   score={score:.3f}  implied_cosine={cos:.3f}  {doc[:60]}...")
    result = generate_stub(q, retrieved) # Remove generate_stub and call the real llm call
    print("   ->", result["answer"][:120], "\n")
# Out:
# Query: What's the refund policy for order #48213?
#    score=0.756  implied_cosine=0.838  Our Q3 refund policy allows exceptions for orders delayed mo...
#    score=0.681  implied_cosine=0.765  Standard refund policy: refunds are issued within 5-7 busine...
#    -> (stub) Based on available context: Our Q3 refund policy allows exceptions for orders delayed more than 10 business days,
#
# Query: What is the capital of France?
#    score=0.512  implied_cosine=0.523  Our shipping partners include BlueDart, Delhivery, and DTDC ...
#    score=0.491  implied_cosine=0.483  Standard refund policy: refunds are issued within 5-7 busine...
#    -> I don't have enough information to answer that.

# %% [markdown]
# **Exercise 5.1 (revised -- read before running):** Look at the `implied_cosine`
# column printed above, not just `score`. Unrelated sentence-embedding
# similarity commonly sits around 0.4-0.6 for models like MiniLM (a known
# effect called *anisotropy* -- embeddings cluster in a narrow cone of the
# vector space rather than spreading out toward 0 for "unrelated" text). This
# means a naive threshold like the original `min_score=0.35` on the raw
# `1/(1+d)` score would **not** reliably abstain on the "capital of France"
# query -- it could easily clear that bar even though nothing in the
# knowledge base is relevant.
#
# Do the following:
# 1. Print `implied_cosine` for both queries above. Does the refund question
#    score meaningfully higher than the capital-of-France question, or are
#    they closer together than you'd expect?
# 2. Try `min_score` values of `0.4`, `0.6`, and `0.8` in `generate_stub`.
#    For each, does the capital-of-France query abstain? Does the *legitimate*
#    refund question still get answered?
# 3. Based on what you find, is there a single threshold that cleanly
#    separates "relevant" from "irrelevant" for this tiny 4-document corpus?
#    If not, what does that tell you about relying on a fixed embedding-
#    similarity cutoff for real-world abstention, and what would you use
#    instead? (Hint: re-read Day 5's grounding-techniques discussion on
#    LLM-as-judge / verification passes -- this is exactly the gap they exist
#    to cover.)
#
# **Then:** set `min_score = 0.0` and re-run. What does the stub generator do
# now, and why is that dangerous in a real system?

# %%
queries = [
    "What's the refund policy for order #48213?",
    "What is the capital of France?"
]

for q in queries:
    retrieved = retrieve(q)

    print("\nQuery:", q)

    for doc, score, cos in retrieved:
        print(f"score={score:.3f}  implied_cosine={cos:.3f}  {doc[:60]}...")
# Out:
# Query: What's the refund policy for order #48213?
# score=0.756  implied_cosine=0.838  Our Q3 refund policy allows exceptions for orders delayed mo...
# score=0.681  implied_cosine=0.765  Standard refund policy: refunds are issued within 5-7 busine...
#
# Query: What is the capital of France?
# score=0.512  implied_cosine=0.523  Our shipping partners include BlueDart, Delhivery, and DTDC ...
# score=0.491  implied_cosine=0.483  Standard refund policy: refunds are issued within 5-7 busine...

# %%
def generate_stub(query: str, retrieved: list, min_score: float = 0.6) -> dict:
    usable = [(doc, cos) for doc, score, cos in retrieved if cos >= min_score]

    if not usable:
        return {
            "answer": "I don't have enough information to answer that.",
            "grounded_in": [],
            "abstained": True
        }

    context = " ".join(doc for doc, _ in usable)

    return {
        "answer": f"(stub) Based on available context: {context[:200]}...",
        "grounded_in": [doc for doc, _ in usable],
        "abstained": False
    }

# %%
queries = [
    "What's the refund policy for order #48213?",
    "What is the capital of France?"
]

thresholds = [0.4, 0.6, 0.8]

for threshold in thresholds:
    print("\n==============================")
    print("min_score =", threshold)

    for q in queries:
        retrieved = retrieve(q)
        result = generate_stub(q, retrieved, min_score=threshold)

        print("\nQuery:", q)
        print("Answer:", result["answer"])
        print("Abstained:", result["abstained"])
# Out:
# ==============================
# min_score = 0.4
#
# Query: What's the refund policy for order #48213?
# Answer: (stub) Based on available context: Our Q3 refund policy allows exceptions for orders delayed more than 10 business days, approved by a supervisor. Order #48213 was delayed 14 days and was granted a full refund on 2025-08-02. Standard r...
# Abstained: False
#
# Query: What is the capital of France?
# Answer: (stub) Based on available context: Our shipping partners include BlueDart, Delhivery, and DTDC for domestic orders across India. Standard refund policy: refunds are issued within 5-7 business days of a return being received....
# Abstained: False
#
# ==============================
# min_score = 0.6
#
# Query: What's the refund policy for order #48213?
# Answer: (stub) Based on available context: Our Q3 refund policy allows exceptions for orders delayed more than 10 business days, approved by a supervisor. Order #48213 was delayed 14 days and was granted a full refund on 2025-08-02. Standard r...
# Abstained: False
#
# Query: What is the capital of France?
# Answer: I don't have enough information to answer that.
# Abstained: True
#
# ==============================
# min_score = 0.8
#
# Query: What's the refund policy for order #48213?
# Answer: (stub) Based on available context: Our Q3 refund policy allows exceptions for orders delayed more than 10 business days, approved by a supervisor. Order #48213 was delayed 14 days and was granted a full refund on 2025-08-02....
# Abstained: False
#
# Query: What is the capital of France?
# Answer: I don't have enough information to answer that.
# Abstained: True

# %% [markdown]
# ## 4. RAG evaluation basics: relevance, faithfulness, groundedness
#
# Three commonly used metrics for evaluating a RAG system (this is the
# simplified, from-scratch version of what libraries like `ragas` compute):
#
# - **Context relevance** — how relevant is each *retrieved chunk* to the
#   question? (Are we retrieving the right thing?)
# - **Faithfulness** — does the *generated answer* only contain claims that
#   are actually supported by the retrieved context? (Is the model
#   hallucinating on top of good retrieval?)
# - **Groundedness** — similar to faithfulness; often used to mean "can every
#   claim in the answer be traced back to a specific source passage."
#
# We'll approximate all three with embedding-similarity heuristics, since we
# don't have a real LLM judge wired in here.

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def context_relevance(query: str, retrieved_docs: list) -> float:

    """Average cosine similarity between the query and each retrieved
    chunk. Higher = retrieval found genuinely relevant material.
    """

    query_emb = model.encode([query])

    doc_embs = model.encode(retrieved_docs)

    sims = cosine_similarity(query_emb, doc_embs)[0]

    return float(np.mean(sims))


def faithfulness(answer: str, retrieved_docs: list) -> float:

    """Approximate faithfulness as the max cosine similarity between the
    answer and any single retrieved chunk -- a real implementation would
    split the answer into individual claims and check each one separately
    against the context (e.g., with an LLM-as-judge or an NLI model).
    """

    if not retrieved_docs:

        return 0.0

    answer_emb = model.encode([answer])

    doc_embs = model.encode(retrieved_docs)

    sims = cosine_similarity(answer_emb, doc_embs)[0]

    return float(np.max(sims))


query = "What's the refund policy for order #48213?"

retrieved = retrieve(query)

retrieved_docs = [doc for doc, _score, _cos in retrieved]

result = generate_stub(query, retrieved)

print("Context relevance:", round(context_relevance(query, retrieved_docs), 3))

print("Faithfulness:      ", round(faithfulness(result["answer"], retrieved_docs), 3))
# Out:
# Context relevance: 0.604
# Faithfulness:       0.957

# %%
retrieved
# Out:
# [('Our Q3 refund policy allows exceptions for orders delayed more than 10 business days, approved by a supervisor. Order #48213 was delayed 14 days and was granted a full refund on 2025-08-02.',
#   0.7557103322159306,
#   0.8383708298206329),
#  ('Standard refund policy: refunds are issued within 5-7 business days of a return being received.',
#   0.6805657080428956,
#   0.7653170824050903)]

# %% [markdown]
# Why embedding similarity falls short here, concretely:
#
# **Topical similarity ≠ factual support**.
# A fabricated claim ("the refund was for ₹50,000") can score high in cosine similarity against the real refund-policy chunk, because it's about the same topic, uses the same vocabulary, and mentions the same entity — even though the specific number is wrong. Cosine similarity has no concept of "this specific fact is or isn't stated in this text"; it only measures overall semantic resemblance.
#
# **NLI models are trained specifically for this**: given a "premise" (the retrieved context) and a "hypothesis" (the claim), they output entailment / contradiction / neutral — a much sharper signal than "how similar are these two vectors."
#
# **LLM-as-judge goes further**: you can literally prompt a model with "Given this context, is the following claim fully supported, partially supported, or not supported? Quote the exact text that supports or contradicts it." This catches contradictions and unsupported specifics that embedding similarity structurally cannot detect, at the cost of an extra LLM call per claim (latency and money).

# %%
def groundedness_report(answer: str, retrieved_docs: list, threshold: float = 0.5) -> dict:
    """Split the answer into rough sentence-level claims and check each
    one against the best-matching retrieved chunk. Returns the fraction of
    claims that clear the similarity threshold ('grounded') plus the
    per-claim detail, so you can see exactly which parts of an answer are
    (or aren't) supported.
    """
    claims = [c.strip() for c in answer.split(".") if c.strip()]
    if not claims or not retrieved_docs:
        return {"grounded_fraction": 0.0, "details": []}

    claim_embs = model.encode(claims)
    doc_embs = model.encode(retrieved_docs)
    sims = cosine_similarity(claim_embs, doc_embs)

    details = []
    grounded_count = 0
    for claim, row in zip(claims, sims):
        best_score = float(np.max(row))
        is_grounded = best_score >= threshold
        grounded_count += is_grounded
        details.append({"claim": claim, "best_score": round(best_score, 3),
                         "grounded": is_grounded})

    return {"grounded_fraction": grounded_count / len(claims), "details": details}

report = groundedness_report(
    "Order 48213 got a full refund because it was delayed. "
    "The moon landing happened in 1969.",   # deliberately inject an unrelated claim
    retrieved_docs,
)
print("Grounded fraction:", round(report["grounded_fraction"], 3))
for d in report["details"]:
    print(f"  [{'OK' if d['grounded'] else 'UNGROUNDED'}] "
          f"(score={d['best_score']})  {d['claim']}")
# Out:
# Grounded fraction: 0.5
#   [OK] (score=0.638)  Order 48213 got a full refund because it was delayed
#   [UNGROUNDED] (score=0.0)  The moon landing happened in 1969

# %% [markdown]
# Notice the injected, unrelated claim about the moon landing scores low and
# gets flagged as ungrounded — this is the core mechanism behind automated
# hallucination detection in RAG evaluation: **check the generated answer's
# claims against the retrieved context, not against general plausibility.**
#
# **Exercise 5.2:** write your own `generate_stub`-style answer that mixes one
# grounded claim with one fabricated (but plausible-sounding) claim about the
# same domain (e.g., invent a fake refund amount). Run it through
# `groundedness_report` — does it catch the fabrication? If not, why might a
# simple cosine-similarity check fail here? (Hint: a fabricated claim can still
# be *topically* similar to the context even if factually wrong — this is a
# real limitation of embedding-based faithfulness checks, and part of why
# production systems often use an LLM-as-judge instead.)

# %% [markdown]
# ## 5. Deliverable: document retrieval experiments + RAG evaluation notebook
#
# For this week's deliverable, extend the pipeline above into a small
# experiment. Suggested structure:
#
# 1. **Build a knowledge base** of 8–12 short documents on a topic of your
#    choice (reuse your Day 2 chunking exercise output, or write new ones).
# 2. **Write 5 test questions**, including:
#    - 2 questions clearly answerable from the knowledge base
#    - 1 question that's a paraphrase (tests semantic vs. keyword retrieval)
#    - 1 question with **no** good answer in the knowledge base (tests
#      abstention)
#    - 1 "trick" question with a false premise (tests whether the model
#      corrects it or plays along)
# 3. **Run each question** through `retrieve()` and `generate_stub()`, and
#    record: the retrieved chunks, the (stub) answer, and whether abstention
#    triggered correctly.
# 4. **Score each answer** with `context_relevance`, `faithfulness`, and
#    `groundedness_report`, and present the results in a small table.
# 5. **Write a 4-6 sentence summary**: where did the pipeline do well? Where
#    did it fail, and which stage (chunking, retrieval, or generation) was
#    responsible for each failure?
#
# This ties together every concept from the week: chunking → embeddings →
# vector storage → retrieval → grounding → evaluation, as one connected
# pipeline rather than five separate topics.

# %%
corpus = [
    "Customers can request a refund for eligible orders through customer support.",
    "Orders delayed by more than 10 business days may qualify for a full refund with supervisor approval.",
    "Standard refunds are processed within 5 to 7 business days after the returned item is received.",
    "Customers should provide their order number when requesting a refund.",
    "Domestic orders in India are shipped through BlueDart, Delhivery, and DTDC.",
    "Customers can track their order using the tracking link sent after shipment.",
    "Customer support is available from 9 AM to 9 PM IST on business days.",
    "Refunds are not automatically approved for every delayed order.",
    "A delayed order may require supervisor approval before a full refund is issued.",
    "Customers can contact support if their tracking information has not been updated."
]

documents = corpus
ids = [f"doc_{i}" for i in range(len(corpus))]

metadatas = [
    {"topic": "refund"} if i in [0, 1, 2, 3, 7, 8]
    else {"topic": "shipping"} if i in [4, 5, 9]
    else {"topic": "support"}
    for i in range(len(corpus))
]

# %%
import chromadb
from chromadb.utils import embedding_functions

chroma_client = chromadb.Client()

local_ef = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="all-MiniLM-L6-v2"
)

collection = chroma_client.get_or_create_collection(
    name="rag_final_practice",
    embedding_function=local_ef
)

# %%
collection.add(
    documents=documents,
    metadatas=metadatas,
    ids=ids
)

# %%
questions = [
    # Clearly answerable
    "Can I get a refund if my order is delayed by more than 10 business days?",

    # Clearly answerable
    "How long do standard refunds usually take?",

    # Paraphrase
    "If my package has been late for over ten working days, can I get my money back?",

    # No answer in knowledge base
    "What is the capital of France?",

    # Trick question / false premise
    "Are all delayed orders automatically eligible for a full refund?"
]

# %%
all_results = []

for question in questions:
    retrieved = retrieve(question)

    result = generate_stub(
        question,
        retrieved,
        min_score=0.6
    )

    retrieved_docs = [doc for doc, score, cos in retrieved]

    print("\n" + "=" * 70)
    print("QUESTION:", question)

    print("\nRETRIEVED:")
    for doc, score, cos in retrieved:
        print(f"cosine={cos:.3f} | {doc}")

    print("\nANSWER:")
    print(result["answer"])

    print("\nABSTAINED:", result["abstained"])

    all_results.append({
        "question": question,
        "retrieved": retrieved,
        "answer": result["answer"],
        "abstained": result["abstained"]
    })
# Out:
# ======================================================================
# QUESTION: Can I get a refund if my order is delayed by more than 10 business days?
#
# RETRIEVED:
# cosine=0.891 | Orders delayed by more than 10 business days may qualify for a full refund with supervisor approval.
# cosine=0.829 | Refunds are not automatically approved for every delayed order.
#
# ANSWER:
# (stub) Based on available context: Orders delayed by more than 10 business days may qualify for a full refund with supervisor approval. Refunds are not automatically approved for every delayed order....
#
# ABSTAINED: False
#
# ======================================================================
# QUESTION: How long do standard refunds usually take?
#
# RETRIEVED:
# cosine=0.941 | Standard refunds are processed within 5 to 7 business days after the returned item is received.
# cosine=0.783 | Refunds are not automatically approved for every delayed order.
#
# ANSWER:
# (stub) Based on available context: Standard refunds are processed within 5 to 7 business days after the returned item is received. Refunds are not automatically approved for every delayed order....
#
# ABSTAINED: False
#
# ======================================================================
# QUESTION: If my package has been late for over ten working days, can I get my money back?
#
# RETRIEVED:
# cosine=0.786 | Orders delayed by more than 10 business days may qualify for a full refund with supervisor approval.
# cosine=0.755 | Refunds are not automatically approved for every delayed order.
#
# ANSWER:
# (stub) Based on available context: Orders delayed by more than 10 business days may qualify for a full refund with supervisor approval. Refunds are not automatically approved for every delayed order....
#
# ABSTAINED: False
#
# ======================================================================
# QUESTION: What is the capital of France?
#
# RETRIEVED:
# cosine=0.511 | Domestic orders in India are shipped through BlueDart, Delhivery, and DTDC.
# cosine=0.478 | Refunds are not automatically approved for every delayed order.
#
# ANSWER:
# I don't have enough information to answer that.
#
# ABSTAINED: True
#
# ======================================================================
# QUESTION: Are all delayed orders automatically eligible for a full refund?
#
# RETRIEVED:
# cosine=0.885 | Refunds are not automatically approved for every delayed order.
# cosine=0.862 | Orders delayed by more than 10 business days may qualify for a full refund with supervisor approval.
#
# ANSWER:
# (stub) Based on available context: Refunds are not automatically approved for every delayed order. Orders delayed by more than 10 business days may qualify for a full refund with supervisor approval....
#
# ABSTAINED: False

# %% [markdown]
# The RAG pipeline worked well for questions that were directly related to the knowledge base because retrieval found relevant refund and shipping information. It also handled the paraphrased refund question reasonably well because semantic retrieval can match similar meanings even when the exact words are different. The main failure can happen with the capital-of-France question if an unrelated document receives a high similarity score, showing that retrieval alone cannot guarantee that an answer is relevant. The trick question also shows that retrieving relevant information is not enough because the generation stage must use the context to correct the false premise instead of agreeing with it. Overall, chunking and embeddings provide the foundation, retrieval finds useful context, and grounding and evaluation are needed to prevent unsupported answers.
